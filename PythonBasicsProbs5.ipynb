# %% [markdown]
# # 217. Contains Duplicate

# %% [markdown]
# Given an integer array nums, return true if any value appears at least twice in the array, and return false if every element is distinct.

# %%
1, 2, 3, 4, 1, 5, 7, 8, 9

# %%
def containsDuplicate(nums):
    
    penguin = {}
    for i in nums:
        
        penguin[i] = []

# %%
    penguin = {}
    for i in [1,2,32,2,15,2]:
        penguin[i] = i  
    penguin[]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-40fe62f6a467> in <cell line: 4>()
#       2 for i in [1,2,32,2,15,2]:
#       3     penguin[i] = i
# ----> 4 penguin[5]
#
# KeyError: 5

# %% [markdown]
# # 1 Create a function which keeps taking an user input until that input integer is negative then returns the sum of all the previous input numbers at the end.
#
# For example, you input 1 -> valid, 2 -> valid, 8 -> valid, -1 -> invalid, thus the function will return the sum of 1, 2 and 8.
#
# def sumTilNegative(): # No argument function
#   sum = 0

# %%
#soodocode

rombus: a variable for user input
floower: a variable that saves all the user inputs
while CONDITION (until rombus is negative):
  floower += rombus

# %%
def sumTilNegative():
  
  floower = 0
  while True:
    rombus = int(input())
    floower += rombus
    if rombus < 0:
      break
  return floower - rombus
print(sumTilNegative())
# Out:
# 1234
# 5123
# -21
# 6357

# %%
A = input()
# Out:
# hi

# %% [markdown]
# #
# 222. Create a function whose elements whose length = 2 get tripled in their length through three-times repetition and added by the first element of it.
#
# Note : You assume every element of the given list is a list (= the given list will be completely nested)
#          Also, you cannot assign the other variables for the list to be returned. That is, you have to modify the elements in-place.
#
# For example, [ [-1,2], [1,3,4,5], [4,5], [5,7], [10] ] ->  [ [-1,2,-1,2,-1,2,-1], [1,3,4,5], [4,5,4,5,4,5,4], [5,7,5,7,5,7,5], [10] ]

# %%
#psooooooodocowd
  
i
for i in nums:
  if len(i) == 2:
    i.extend(i*2 + i[0])
  else: pass

# %%
# Out:
# 2

# %%
def funnyProblem(nums):
  for i in range(len(nums)):
    if len(nums[i]) == 2:
     nums[i].extend(nums[i]*2+[nums[i][0]])
    else: pass
  return nums

funnyProblem([ [-1,2], [1,3,4,5], [4,5], [5,7], [10] ])
# Out:
# [[-1, 2, -1, 2, -1, 2, -1],
#  [1, 3, 4, 5],
#  [4, 5, 4, 5, 4, 5, 4],
#  [5, 7, 5, 7, 5, 7, 5],
#  [10]]

# %%
import bacon

# %%
a = [[1,2], [1,3]]

a[1].extend([1,4])

# %%
a
# Out:
# [[1, 2], [1, 3, 1, 4]]
